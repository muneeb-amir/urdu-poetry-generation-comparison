# %%
# COMPLETE SETUP CELL - Run this FIRST

from google.colab import drive
import os

# Mount Drive (skip if already mounted)
try:
    drive.mount('/content/drive', force_remount=False)
except:
    pass  # Already mounted

# Navigate to project folder
# Update this path to match your project location in Google Drive
project_path = '/content/drive/MyDrive/DLP_project'  # Change this to your actual path
os.chdir(project_path)

# Change to notebooks folder (so ../results/ and ../data/ paths work)
os.chdir('notebooks')

print(f"Current directory: {os.getcwd()}")
print(f"Can access data/processed: {os.path.exists('../data/processed')}")
print(f"Can access results: {os.path.exists('../results')}")
# Out:
# Mounted at /content/drive
# Current directory: /content/drive/MyDrive/DLP_project/notebooks
# Can access data/processed: True
# Can access results: True

# %% [markdown]
# # Simple RNN Training
#
# This notebook trains Simple RNN models for Urdu poetry generation using three different optimizers: Adam, RMSprop, and SGD.

# %%
# Install required libraries
# !pip install -q tensorflow numpy pandas matplotlib

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import pickle
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import EarlyStopping

# Set random seeds for reproducibility
np.random.seed(42)
import tensorflow as tf
tf.random.set_seed(42)

# Create directories
os.makedirs('results', exist_ok=True)

# %% [markdown]
# ## Load Processed Data

# %%
# Load processed data
X_train = np.load('../data/processed/X_train.npy')
y_train = np.load('../data/processed/y_train.npy')
X_val = np.load('../data/processed/X_val.npy')
y_val = np.load('../data/processed/y_val.npy')
X_test = np.load('../data/processed/X_test.npy')
y_test = np.load('../data/processed/y_test.npy')

# Load tokenizer and metadata
with open('../data/processed/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

with open('../data/processed/metadata.pkl', 'rb') as f:
    metadata = pickle.load(f)

vocab_size = metadata['vocab_size']
sequence_length = metadata['sequence_length']

print(f"Data loaded successfully!")
print(f"Vocabulary size: {vocab_size}")
print(f"Sequence length: {sequence_length}")
print(f"Train samples: {len(X_train)}")
print(f"Validation samples: {len(X_val)}")
print(f"Test samples: {len(X_test)}")
# Out:
# Data loaded successfully!
# Vocabulary size: 10505
# Sequence length: 20
# Train samples: 16865
# Validation samples: 2108
# Test samples: 2109

# %% [markdown]
# ## Build Simple RNN Model

# %%
def build_rnn_model(vocab_size, sequence_length, embedding_dim=128, rnn_units=256):
    """Build a Simple RNN model for next-word prediction"""
    model = Sequential([
        Embedding(vocab_size, embedding_dim, input_length=sequence_length),
        SimpleRNN(rnn_units, return_sequences=False),
        Dense(vocab_size, activation='softmax')
    ])
    return model

# Hyperparameters
EMBEDDING_DIM = 128
RNN_UNITS = 256
BATCH_SIZE = 128
EPOCHS = 25
LEARNING_RATE = 0.001

print("Model architecture defined!")
# Out:
# Model architecture defined!

# %% [markdown]
# ## Training Function

# %%
def train_model(optimizer_name, optimizer):
    """Train RNN model with specified optimizer"""
    print(f"\n{'='*60}")
    print(f"Training RNN with {optimizer_name} optimizer")
    print(f"{'='*60}\n")

    # Build model
    model = build_rnn_model(vocab_size, sequence_length, EMBEDDING_DIM, RNN_UNITS)
    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    # Early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    )

    # Record start time
    start_time = time.time()

    # Train model
    history = model.fit(
        X_train, y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping],
        verbose=1
    )

    # Record end time
    training_time = time.time() - start_time

    # Evaluate on all sets
    train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
    val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)

    # Compute perplexity
    perplexity = np.exp(test_loss)

    # Save model
    model.save(f'../models/rnn_{optimizer_name.lower()}.h5')

    return {
        'model': model,
        'history': history,
        'train_loss': train_loss,
        'val_loss': val_loss,
        'test_loss': test_loss,
        'perplexity': perplexity,
        'training_time': training_time
    }

# %% [markdown]
# ## Train with Adam Optimizer

# %%
os.makedirs('models', exist_ok=True)

adam_optimizer = Adam(learning_rate=LEARNING_RATE)
adam_results = train_model('Adam', adam_optimizer)
# Out:
# ============================================================
# Training RNN with Adam optimizer
# ============================================================
#
# Epoch 1/25
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.1118 - loss: 6.8947 - val_accuracy: 0.1101 - val_loss: 6.0006
# Epoch 2/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1171 - loss: 5.7605 - val_accuracy: 0.1101 - val_loss: 5.9066
# Epoch 3/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1178 - loss: 5.5713 - val_accuracy: 0.1181 - val_loss: 5.8185
# Epoch 4/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1519 - loss: 5.2291 - val_accuracy: 0.1523 - val_loss: 5.6497
# Epoch 5/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1904 - loss: 4.8341 - val_accuracy: 0.1741 - val_loss: 5.4948
# Epoch 6/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2356 - loss: 4.4203 - val_accuracy: 0.1983 - val_loss: 5.4193
# Epoch 7/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2634 - loss: 4.2071 - val_accuracy: 0.2073 - val_loss: 5.3512
# Epoch 8/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2945 - loss: 3.9675 - val_accuracy: 0.2135 - val_loss: 5.3080
# Epoch 9/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3397 - loss: 3.5719 - val_accuracy: 0.2149 - val_loss: 5.3165
# Epoch 10/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3755 - loss: 3.2592 - val_accuracy: 0.2310 - val_loss: 5.3813
# Epoch 11/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4142 - loss: 2.9575 - val_accuracy: 0.2381 - val_loss: 5.4742
# Epoch 12/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4570 - loss: 2.6762 - val_accuracy: 0.2415 - val_loss: 5.5693
# Epoch 13/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5027 - loss: 2.4383 - val_accuracy: 0.2424 - val_loss: 5.6594
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Train with RMSprop Optimizer

# %%
rmsprop_optimizer = RMSprop(learning_rate=LEARNING_RATE)
rmsprop_results = train_model('RMSprop', rmsprop_optimizer)
# Out:
# ============================================================
# Training RNN with RMSprop optimizer
# ============================================================
#
# Epoch 1/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - accuracy: 0.1045 - loss: 6.7804 - val_accuracy: 0.1101 - val_loss: 5.9738
# Epoch 2/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 5.9116 - val_accuracy: 0.1101 - val_loss: 5.9648
# Epoch 3/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1171 - loss: 5.8952 - val_accuracy: 0.1101 - val_loss: 5.9584
# Epoch 4/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1171 - loss: 5.8775 - val_accuracy: 0.1101 - val_loss: 5.9399
# Epoch 5/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1171 - loss: 5.8270 - val_accuracy: 0.1110 - val_loss: 5.8437
# Epoch 6/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1193 - loss: 5.6803 - val_accuracy: 0.1034 - val_loss: 5.7533
# Epoch 7/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.1228 - loss: 5.5407 - val_accuracy: 0.1120 - val_loss: 5.6803
# Epoch 8/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1316 - loss: 5.4190 - val_accuracy: 0.1143 - val_loss: 5.6135
# Epoch 9/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1432 - loss: 5.2869 - val_accuracy: 0.1366 - val_loss: 5.5210
# Epoch 10/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1582 - loss: 5.1303 - val_accuracy: 0.1603 - val_loss: 5.4207
# Epoch 11/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1779 - loss: 4.9588 - val_accuracy: 0.1713 - val_loss: 5.3155
# Epoch 12/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1981 - loss: 4.8902 - val_accuracy: 0.1746 - val_loss: 5.3212
# Epoch 13/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.2139 - loss: 4.7573 - val_accuracy: 0.1812 - val_loss: 5.2322
# Epoch 14/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.2252 - loss: 4.7171 - val_accuracy: 0.1931 - val_loss: 5.1571
# Epoch 15/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.2438 - loss: 4.3827 - val_accuracy: 0.2011 - val_loss: 5.1257
# Epoch 16/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.2608 - loss: 4.2599 - val_accuracy: 0.2111 - val_loss: 5.0724
# Epoch 17/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.2767 - loss: 4.1113 - val_accuracy: 0.2201 - val_loss: 5.0385
# Epoch 18/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.2940 - loss: 3.9741 - val_accuracy: 0.2249 - val_loss: 5.0066
# Epoch 19/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3130 - loss: 3.8412 - val_accuracy: 0.2386 - val_loss: 4.9784
# Epoch 20/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3311 - loss: 3.6972 - val_accuracy: 0.2391 - val_loss: 4.9928
# Epoch 21/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.3529 - loss: 3.5640 - val_accuracy: 0.2329 - val_loss: 4.9806
# Epoch 22/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3691 - loss: 3.4276 - val_accuracy: 0.2372 - val_loss: 4.9865
# Epoch 23/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3795 - loss: 3.3824 - val_accuracy: 0.2462 - val_loss: 5.0410
# Epoch 24/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3981 - loss: 3.2525 - val_accuracy: 0.2514 - val_loss: 4.9652
# Epoch 25/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4235 - loss: 3.0637 - val_accuracy: 0.2543 - val_loss: 4.9696
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Train with SGD Optimizer

# %%
sgd_optimizer = SGD(learning_rate=LEARNING_RATE)
sgd_results = train_model('SGD', sgd_optimizer)
# Out:
# ============================================================
# Training RNN with SGD optimizer
# ============================================================
#
# Epoch 1/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 2.7917e-04 - loss: 9.2580 - val_accuracy: 0.0128 - val_loss: 9.2487
# Epoch 2/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0503 - loss: 9.2451 - val_accuracy: 0.1101 - val_loss: 9.2306
# Epoch 3/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1171 - loss: 9.2221 - val_accuracy: 0.1101 - val_loss: 9.1893
# Epoch 4/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1171 - loss: 9.1681 - val_accuracy: 0.1101 - val_loss: 9.0995
# Epoch 5/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1171 - loss: 9.0605 - val_accuracy: 0.1101 - val_loss: 8.9538
# Epoch 6/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1171 - loss: 8.8941 - val_accuracy: 0.1101 - val_loss: 8.7492
# Epoch 7/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1171 - loss: 8.6662 - val_accuracy: 0.1101 - val_loss: 8.4922
# Epoch 8/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1171 - loss: 8.3926 - val_accuracy: 0.1101 - val_loss: 8.2371
# Epoch 9/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1171 - loss: 8.1469 - val_accuracy: 0.1101 - val_loss: 8.0726
# Epoch 10/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.9938 - val_accuracy: 0.1101 - val_loss: 7.9489
# Epoch 11/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.8694 - val_accuracy: 0.1101 - val_loss: 7.8239
# Epoch 12/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.7442 - val_accuracy: 0.1101 - val_loss: 7.6990
# Epoch 13/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.6209 - val_accuracy: 0.1101 - val_loss: 7.5810
# Epoch 14/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 7.5059 - val_accuracy: 0.1101 - val_loss: 7.4750
# Epoch 15/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 7.4034 - val_accuracy: 0.1101 - val_loss: 7.3811
# Epoch 16/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.3123 - val_accuracy: 0.1101 - val_loss: 7.2963
# Epoch 17/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.2298 - val_accuracy: 0.1101 - val_loss: 7.2186
# Epoch 18/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1171 - loss: 7.1544 - val_accuracy: 0.1101 - val_loss: 7.1473
# Epoch 19/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 7.0854 - val_accuracy: 0.1101 - val_loss: 7.0820
# Epoch 20/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 7.0225 - val_accuracy: 0.1101 - val_loss: 7.0226
# Epoch 21/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 6.9655 - val_accuracy: 0.1101 - val_loss: 6.9689
# Epoch 22/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 6.9139 - val_accuracy: 0.1101 - val_loss: 6.9205
# Epoch 23/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 6.8673 - val_accuracy: 0.1101 - val_loss: 6.8767
# Epoch 24/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1171 - loss: 6.8252 - val_accuracy: 0.1101 - val_loss: 6.8370
# Epoch 25/25
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1171 - loss: 6.7869 - val_accuracy: 0.1101 - val_loss: 6.8008
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Save Results to CSV

# %%
# Prepare results
results_data = [
    {
        'model': 'RNN',
        'optimizer': 'Adam',
        'train_loss': adam_results['train_loss'],
        'val_loss': adam_results['val_loss'],
        'test_loss': adam_results['test_loss'],
        'perplexity': adam_results['perplexity'],
        'training_time': adam_results['training_time']
    },
    {
        'model': 'RNN',
        'optimizer': 'RMSprop',
        'train_loss': rmsprop_results['train_loss'],
        'val_loss': rmsprop_results['val_loss'],
        'test_loss': rmsprop_results['test_loss'],
        'perplexity': rmsprop_results['perplexity'],
        'training_time': rmsprop_results['training_time']
    },
    {
        'model': 'RNN',
        'optimizer': 'SGD',
        'train_loss': sgd_results['train_loss'],
        'val_loss': sgd_results['val_loss'],
        'test_loss': sgd_results['test_loss'],
        'perplexity': sgd_results['perplexity'],
        'training_time': sgd_results['training_time']
    }
]

# Create or append to results.csv
df = pd.DataFrame(results_data)
if os.path.exists('../results/results.csv'):
    existing_df = pd.read_csv('../results/results.csv')
    df = pd.concat([existing_df, df], ignore_index=True)
df.to_csv('../results/results.csv', index=False)

print("Results saved to results/results.csv")
print("\nResults Summary:")
print(df.to_string(index=False))
# Out:
# Results saved to results/results.csv
#
# Results Summary:
# model optimizer  train_loss  val_loss  test_loss  perplexity  training_time
#   RNN      Adam    3.616657  5.308016   5.263339  193.125269      22.809120
#   RNN   RMSprop    3.318506  4.965223   4.934547  139.010216      53.675207
#   RNN       SGD    6.767591  6.800785   6.752016  855.782339      34.678181
# /tmp/ipython-input-156321046.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([existing_df, df], ignore_index=True)

# %% [markdown]
# ## Training & Validation Loss Curves

# %%
# Plot loss curves for all optimizers
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

optimizers = ['Adam', 'RMSprop', 'SGD']
results_list = [adam_results, rmsprop_results, sgd_results]

for idx, (opt_name, result) in enumerate(zip(optimizers, results_list)):
    history = result['history']
    ax = axes[idx]

    ax.plot(history.history['loss'], label='Train Loss', marker='o')
    ax.plot(history.history['val_loss'], label='Validation Loss', marker='s')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.set_title(f'RNN - {opt_name} Optimizer')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Final Evaluation Metrics

# %%
# Display metrics table
metrics_df = pd.DataFrame({
    'Optimizer': ['Adam', 'RMSprop', 'SGD'],
    'Train Loss': [adam_results['train_loss'], rmsprop_results['train_loss'], sgd_results['train_loss']],
    'Val Loss': [adam_results['val_loss'], rmsprop_results['val_loss'], sgd_results['val_loss']],
    'Test Loss': [adam_results['test_loss'], rmsprop_results['test_loss'], sgd_results['test_loss']],
    'Perplexity': [adam_results['perplexity'], rmsprop_results['perplexity'], sgd_results['perplexity']],
    'Training Time (s)': [adam_results['training_time'], rmsprop_results['training_time'], sgd_results['training_time']]
})

print("=" * 80)
print("RNN Model - Final Evaluation Metrics")
print("=" * 80)
print(metrics_df.to_string(index=False))
print("=" * 80)
# Out:
# ================================================================================
# RNN Model - Final Evaluation Metrics
# ================================================================================
# Optimizer  Train Loss  Val Loss  Test Loss  Perplexity  Training Time (s)
#      Adam    3.616657  5.308016   5.263339  193.125269          22.809120
#   RMSprop    3.318506  4.965223   4.934547  139.010216          53.675207
#       SGD    6.767591  6.800785   6.752016  855.782339          34.678181
# ================================================================================
